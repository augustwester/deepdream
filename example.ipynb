# %%
import numpy as np
from dream import dream, zoom_dream
from PIL import Image
from helpers import random_noise, show

# %% [markdown]
# ## Load the image

# %%
img = Image.open("flowers.jpg")
show(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x675 at 0x108AFFC40>

# %% [markdown]
# ## Define feature maps / channels to optimize

# %%
settings = {
    "Mixed_5b": "all",
    "Mixed_5c": None,
    "Mixed_5d": None,
    "Mixed_6a": None,
    "Mixed_6b": None,
    "Mixed_6c": None,
    "Mixed_6d": None,
    "Mixed_6e": None,
    "Mixed_7a": None,
    "Mixed_7b": None,
    "Mixed_7c": None,
}

# %%
img_dream = dream(img, num_octaves=3, steps_per_octave=100, settings=settings)
img_dream.save("dream.png")
# Out:
# <PIL.Image.Image image mode=RGB size=900x675 at 0x1114C2940>
