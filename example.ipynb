# %%
import numpy as np
from dream import dream, zoom_dream
from PIL import Image
from helpers import random_noise, show

# %%
#img = Image.open("flowers.jpg")
img = random_noise(300, 300)
show(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1067AC460>

# %%
#channel = np.random.randint(0, 100)
channel = 94

settings = {
    "Mixed_5b": None,
    "Mixed_5c": None,
    "Mixed_5d": None,
    "Mixed_6a": None,
    "Mixed_6b": (channel,),
    "Mixed_6c": None,
    "Mixed_6d": None,
    "Mixed_6e": None,
    "Mixed_7a": None,
    "Mixed_7b": None,
    "Mixed_7c": None,
}

print("Picked channel", channel)
# Out:
# Picked channel 94

# %%
noise = random_noise(300, 300)
zoom_dream(noise, num_frames=50, steps_per_frame=100, settings=settings)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x10F1377F0>
# Processing octave #1 with shape torch.Size([1, 3, 300, 300])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ff45b4a9cad0> in <module>
#       1 noise = random_noise(300, 300)
# ----> 2 zoom_dream(noise, num_frames=50, steps_per_frame=100, settings=settings)
#
# ~/Desktop/deep-dream/dream.py in zoom_dream(img, num_frames, steps_per_frame, settings)
#      88     for i in range(num_frames-1):
#      89         img = zoom(img)
# ---> 90         img = dream(img, num_octaves=1, steps_per_octave=steps_per_frame, settings=settings, model=model)
#      91         frames.append(img)
#      92     return frames
#
# ~/Desktop/deep-dream/dream.py in dream(img, num_octaves, steps_per_octave, settings, lr, model)
#      63
#      64         if dream is None:
# ...
